# %% [markdown]
# # Importação da biblioteca

# %%
import pandas as pd

# %% [markdown]
# # Criando um dataframe pandas a partir de listas

# %%
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %% [markdown]
# # Exibindo informações gerais do dataframe pandas

# %%
# Exibindo o número de linhas e colunas de uma dataframe
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.shape
# Out:
# (6, 5)

# %%
# Exibindo uma linha do dataframe aleatóriamente
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.sample()
# Out:
#     nome  idade  altura  peso sexo
# 2  Pedro     65    1.75    87    M

# %%
# Exibindo mais uma linha do dataframe aleatóriamente
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.sample(3)
# Out:
#       nome  idade  altura  peso sexo
# 5    Ester     37    1.73    68    F
# 4  Eduardo     42    1.82    96    M
# 0  Douglas     45    1.85    70    M

# %%
# Exibindo os tipos de dados em um dataframe
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.dtypes
# Out:
# nome       object
# idade       int64
# altura    float64
# peso        int64
# sexo       object
# dtype: object

# %%
#Exibindo os tipos de dados e outras informações do dataframe
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nome    6 non-null      object
#  1   idade   6 non-null      int64
#  2   altura  6 non-null      float64
#  3   peso    6 non-null      int64
#  4   sexo    6 non-null      object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 368.0+ bytes

# %%
# Exibir informações do índice do dataframe
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# Criando um dataframe com rótulo
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
medidas = df.describe()
display(medidas)
# Out:
#            idade   altura       peso
# count   6.000000  6.00000   6.000000
# mean   43.333333  1.67500  67.833333
# std    21.266562  0.22731  25.615750
# min     7.000000  1.23000  22.000000
# 25%    38.250000  1.68500  65.000000
# 50%    43.500000  1.74000  69.000000
# 75%    59.250000  1.80250  82.750000
# max    65.000000  1.85000  96.000000

# %%
# Exibir informações do índice do dataframe com rótulo
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
medidas.index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
# Exibindo apenas as primeiras linhas de um dataframe
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.head()
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M

# %%
# Exibindo apenas as últimas linhas de um dataframe
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.tail()
# Out:
#       nome  idade  altura  peso sexo
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %% [markdown]
# # Fatiamento de linhas de um dataframe

# %%
# Exibir as informações de uma linha por rótulo
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
#display(df)
df.loc[0]
# Out:
# nome      Douglas
# idade          45
# altura       1.85
# peso           70
# sexo            M
# Name: 0, dtype: object

# %%
# Criando um df com rótulo do índice como texto
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
medidas = df.describe()
#display(medidas)
#exibir as informações de uma linha pelo rótulo
medidas.loc['count']
# Out:
# idade     6.0
# altura    6.0
# peso      6.0
# Name: count, dtype: float64

# %%
'''
Temos
1 - df (todas as informações)
2 - medidas (tabela só com as estatísiticas )
'''

# %%
'''
Resumo da seção o método loc procura um rótulo, que por sua
vez dependendo do dataframe, poder ser um rótulo de texto, ou
um rótulo de número, quando usamos a função display, sempre
será exibido o rótulo da linha, seja ele texto ou número.
'''

# %%
# guardando os valores fatiados em um objeto pandas
'''
Ao fatiarmos um dataframe pandas e armazená-lo, automaticamente o fatiamento
será convertido em outro dataframe (subtabela da tabela original)
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
sub_tabela = df.loc[0]
display(sub_tabela)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
# nome      Douglas
# idade          45
# altura       1.85
# peso           70
# sexo            M
# Name: 0, dtype: object

# %%
# guardando os valores fatiados em um objeto Python puro (lista)
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
sub_tabela = list(df.loc[0])
print(sub_tabela)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
# ['Douglas', 45, 1.85, 70, 'M']

# %%
# Exibindo mais de uma linha pelo rótulo
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
df.loc[[0,2,4]]
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 2    Pedro     65    1.75    87    M
# 4  Eduardo     42    1.82    96    M

# %%
# armazenando mais de uma linha pelo rótulo
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
sub2 = df.loc[[0,2,4]]
display(sub2)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 2    Pedro     65    1.75    87    M
# 4  Eduardo     42    1.82    96    M

# %%
'''
Agora vamos supor que desejamos armazenar uma subtabela da tabela medidas
apenas com as linhas de média e desvio padrão, fatiadas pelo rótulo
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
medidas = df.describe()
display(medidas)
sub3 = medidas.loc[['mean','std']]
display(sub3)
# Out:
#            idade   altura       peso
# count   6.000000  6.00000   6.000000
# mean   43.333333  1.67500  67.833333
# std    21.266562  0.22731  25.615750
# min     7.000000  1.23000  22.000000
# 25%    38.250000  1.68500  65.000000
# 50%    43.500000  1.74000  69.000000
# 75%    59.250000  1.80250  82.750000
# max    65.000000  1.85000  96.000000
#           idade   altura       peso
# mean  43.333333  1.67500  67.833333
# std   21.266562  0.22731  25.615750

# %%
'''
Agora vamos supor que desejamos armazenar uma subtabela da tabela medidas
apenas com as linhas da tabela original, fatiadas pelo rótulo e exibidas
e armazenadas em ordem diferente da original
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(medidas)
sub4 = medidas.loc[['min','25%','50%','75%','max','count','mean','std']]
display(sub4)
# Out:
#            idade   altura       peso
# count   6.000000  6.00000   6.000000
# mean   43.333333  1.67500  67.833333
# std    21.266562  0.22731  25.615750
# min     7.000000  1.23000  22.000000
# 25%    38.250000  1.68500  65.000000
# 50%    43.500000  1.74000  69.000000
# 75%    59.250000  1.80250  82.750000
# max    65.000000  1.85000  96.000000
#            idade   altura       peso
# min     7.000000  1.23000  22.000000
# 25%    38.250000  1.68500  65.000000
# 50%    43.500000  1.74000  69.000000
# 75%    59.250000  1.80250  82.750000
# max    65.000000  1.85000  96.000000
# count   6.000000  6.00000   6.000000
# mean   43.333333  1.67500  67.833333
# std    21.266562  0.22731  25.615750

# %%
# Exibindo linhas por índices em um dataframe com rótulo e índice numérico
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.iloc[0]
# Out:
# nome      Douglas
# idade          45
# altura       1.85
# peso           70
# sexo            M
# Name: 0, dtype: object

# %%
# Exibindo linhas por índices em um dataframe com rótulo textual e índice numérico
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
medidas = df.describe()
display(medidas)
medidas.iloc[0]
# Out:
#            idade   altura       peso
# count   6.000000  6.00000   6.000000
# mean   43.333333  1.67500  67.833333
# std    21.266562  0.22731  25.615750
# min     7.000000  1.23000  22.000000
# 25%    38.250000  1.68500  65.000000
# 50%    43.500000  1.74000  69.000000
# 75%    59.250000  1.80250  82.750000
# max    65.000000  1.85000  96.000000
# idade     6.0
# altura    6.0
# peso      6.0
# Name: count, dtype: float64

# %%
# Exibindo mais de uma linha por índices em um dataframe com rótulo textual e índice numérico
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
medidas = df.describe()
display(medidas)
medidas.iloc[[0,1,2]]
# Out:
#            idade   altura       peso
# count   6.000000  6.00000   6.000000
# mean   43.333333  1.67500  67.833333
# std    21.266562  0.22731  25.615750
# min     7.000000  1.23000  22.000000
# 25%    38.250000  1.68500  65.000000
# 50%    43.500000  1.74000  69.000000
# 75%    59.250000  1.80250  82.750000
# max    65.000000  1.85000  96.000000
#            idade   altura       peso
# count   6.000000  6.00000   6.000000
# mean   43.333333  1.67500  67.833333
# std    21.266562  0.22731  25.615750

# %% [markdown]
# # Fatiamento de colunas de um dataframe

# %%
# Fatiando uma coluna pelo seu rótulo
'''
Agora vamos buscar todas as linhas do dataframe original para a coluna
nome
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.loc[:,'nome']
# Out:
# 0    Douglas
# 1    Daniela
# 2      Pedro
# 3      Maria
# 4    Eduardo
# 5      Ester
# Name: nome, dtype: object

# %%
# Armazenando a tabela anterior em uma variável (sub5)
'''
Agora vamos buscar todas as linhas do dataframe original para a coluna
nome
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
sub5 = df.loc[:,'nome']
display(sub5)
# Out:
# 0    Douglas
# 1    Daniela
# 2      Pedro
# 3      Maria
# 4    Eduardo
# 5      Ester
# Name: nome, dtype: object

# %%
# Fatiando mais de uma coluna pelo seu rótulo
'''
Agora vamos buscar todas as linhas do dataframe original para as colunas
nome e idade
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.loc[:,['nome','idade']]
# Out:
#       nome  idade
# 0  Douglas     45
# 1  Daniela      7
# 2    Pedro     65
# 3    Maria     64
# 4  Eduardo     42
# 5    Ester     37

# %%
# Fatiando mais de uma coluna pelo seu rótulo
'''
Agora vamos buscar as linhas 0, 2 e 4 do dataframe original para as colunas
nome e idade
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.loc[[0,2,4],['nome','idade']]
# Out:
#       nome  idade
# 0  Douglas     45
# 2    Pedro     65
# 4  Eduardo     42

# %%
'''
Agora vamos criar a tabela medidas como um describe da tabela original
e fatiar pelo rótulo o desvio padrão e média para as idades e para o peso
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
medidas = df.describe()
#display(medidas)
medidas.loc[['std','mean'],['idade','peso']]
# Out:
#           idade       peso
# std   21.266562  25.615750
# mean  43.333333  67.833333

# %%
# Exibindo colunas pelo índice
'''
Vamos exibir a coluna nome e todas as suas linhas
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.iloc[:,0]
# Out:
# 0    Douglas
# 1    Daniela
# 2      Pedro
# 3      Maria
# 4    Eduardo
# 5      Ester
# Name: nome, dtype: object

# %%
# Exibindo colunas pelo índice
'''
Vamos exibir a coluna nome, a coluna idade e todas as suas linhas
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.iloc[:,[0,1]]
# Out:
#       nome  idade
# 0  Douglas     45
# 1  Daniela      7
# 2    Pedro     65
# 3    Maria     64
# 4  Eduardo     42
# 5    Ester     37

# %%
# Alternativa 01 para exibir todas as linhas de uma coluna
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['nome']
# Out:
# 0    Douglas
# 1    Daniela
# 2      Pedro
# 3      Maria
# 4    Eduardo
# 5      Ester
# Name: nome, dtype: object

# %%
# Alternativa 02 para exibir todas as linhas de uma coluna
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.nome
# Out:
# 0    Douglas
# 1    Daniela
# 2      Pedro
# 3      Maria
# 4    Eduardo
# 5      Ester
# Name: nome, dtype: object

# %% [markdown]
# # Fatiamento de células (cruzamento de linha com coluna) de um dataframe

# %%
# Fatiando uma célula pelo seu rótulo
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
'''
imagine que você deseja saber a idade de Douglas
'''
df.loc[0,'idade']
# Out:
# 45

# %%
# Fatiando uma célula pelo seu índice
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
'''
imagine que você deseja saber a idade de Douglas
'''
df.iloc[0,1]
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
# 45

# %%
'''
Agora vamos buscar a coluna idade pelo seu rótulo e a linha 0
pelo seu índice
'''
# Fatiando uma célula pelo seu índice
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
df['idade'][0]

# %%
'''
Existe um método alternativo ao loc para exibir uma célula pelo
seus rótulos de linha e coluna
Exemplo:
Imagine que você deseja saber a idade presente na linha de rótulo 0
'''
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.at[0,'idade']
# Out:
# 45

# %%
'''
Existe um método alternativo ao iloc para exibir uma célula pelos
seus índices de linha e coluna
Exemplo:
Imagine que você deseja saber a idade presente na linha de rótulo 0
'''
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df.iat[0,1]
# Out:
# 45

# %% [markdown]
# # Operacões que modificam o dataframe original

# %%
# renomear colunas método 01
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
'''
Vamos renomear as colunas peso (massa) e sexo (genero)
'''
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     45    1.85     70      M
# 1  Daniela      7    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     37    1.73     68      F

# %%
# renomear colunas médoto 02
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
'''
Vamos renomear as colunas peso (massa) e sexo (genero)
'''
df = df.rename(columns={'peso':'massa','sexo':'genero'})
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     45    1.85     70      M
# 1  Daniela      7    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     37    1.73     68      F

# %%
# renomear colunas médoto 03
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
'''
Vamos renomear as colunas peso (massa) e sexo (genero)
'''
df.rename({'peso':'massa','sexo':'genero'}, axis=1)
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# renomear colunas médoto 04
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
'''
Vamos renomear as colunas peso (massa) e sexo (genero)
'''
df = df.rename({'peso':'massa','sexo':'genero'}, axis='columns')
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     45    1.85     70      M
# 1  Daniela      7    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     37    1.73     68      F

# %%
# renomear colunas médoto 05
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
'''
Vamos renomear as colunas peso (massa) e depois sexo (genero)
'''
df.columns.values[3] = 'massa'
df.columns.values[4] = 'genero'
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     45    1.85     70      M
# 1  Daniela      7    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     37    1.73     68      F

# %%
# renomeando linhas método 01
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
'''
Agora vamos supor que desejamos renomear a linha 0 (pai) e
a linha 1 (filha)
'''
df = df.rename({0:'pai',1:'filha'}, axis=0)
display(df)
# Out:
#           nome  idade  altura  peso sexo
# pai    Douglas     45    1.85    70    M
# filha  Daniela      7    1.23    22    F
# 2        Pedro     65    1.75    87    M
# 3        Maria     64    1.67    64    F
# 4      Eduardo     42    1.82    96    M
# 5        Ester     37    1.73    68    F

# %%
# renomeando linhas método 02
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
'''
Agora vamos supor que desejamos renomear a linha 0 (pai) e
a linha 1 (filha)
'''
df = df.rename({0:'pai',1:'filha'}, axis='rows')
display(df)
# Out:
#           nome  idade  altura  peso sexo
# pai    Douglas     45    1.85    70    M
# filha  Daniela      7    1.23    22    F
# 2        Pedro     65    1.75    87    M
# 3        Maria     64    1.67    64    F
# 4      Eduardo     42    1.82    96    M
# 5        Ester     37    1.73    68    F

# %%
# resetando os rótulos do índice
'''
Ao aplicarmos o método reset_index criamos um novo índice com
rótulo numérico e o rótulo anterior vira uma nova coluna no dataframe
'''
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df = df.rename({0:'pai',1:'filha'}, axis='rows')
display(df)
df.reset_index(inplace=True)
display(df)
# Out:
#           nome  idade  altura  peso sexo
# pai    Douglas     45    1.85    70    M
# filha  Daniela      7    1.23    22    F
# 2        Pedro     65    1.75    87    M
# 3        Maria     64    1.67    64    F
# 4      Eduardo     42    1.82    96    M
# 5        Ester     37    1.73    68    F
#    index     nome  idade  altura  peso sexo
# 0    pai  Douglas     45    1.85    70    M
# 1  filha  Daniela      7    1.23    22    F
# 2      2    Pedro     65    1.75    87    M
# 3      3    Maria     64    1.67    64    F
# 4      4  Eduardo     42    1.82    96    M
# 5      5    Ester     37    1.73    68    F

# %%
# excluindo colunas
'''
Ao aplicarmos o método reset_index criamos um novo índice com
rótulo numérico e o rótulo anterior vira uma nova coluna no dataframe
'''
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df = df.rename({0:'pai',1:'filha'}, axis='rows')
display(df)
df.reset_index(inplace=True)
display(df)
'''
Agora vamos excluir a coluna gerada automaticamente no momento
em que resetamos o índice
'''
df.drop('index',axis=1,inplace=True)
display(df)
# Out:
#           nome  idade  altura  peso sexo
# pai    Douglas     45    1.85    70    M
# filha  Daniela      7    1.23    22    F
# 2        Pedro     65    1.75    87    M
# 3        Maria     64    1.67    64    F
# 4      Eduardo     42    1.82    96    M
# 5        Ester     37    1.73    68    F
#    index     nome  idade  altura  peso sexo
# 0    pai  Douglas     45    1.85    70    M
# 1  filha  Daniela      7    1.23    22    F
# 2      2    Pedro     65    1.75    87    M
# 3      3    Maria     64    1.67    64    F
# 4      4  Eduardo     42    1.82    96    M
# 5      5    Ester     37    1.73    68    F
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# excluindo linhas
'''
Ao aplicarmos o método reset_index criamos um novo índice com
rótulo numérico e o rótulo anterior vira uma nova coluna no dataframe
'''
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
'''
Agora vamos excluir a coluna gerada automaticamente no momento
em que resetamos o índice
'''
df.drop(0,axis=0,inplace=True)
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade  altura  peso sexo
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# substituindo o valor de uma célula
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
'''
Imagine que você deseja substituir a idade de Maria (64) pelo
valor 65
'''
df['idade'][3] = 65
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
# <ipython-input-135-e87c1940991d>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['idade'][3] = 65
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     65    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# substituindo o valor de uma célula
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
'''
Imagine que você deseja substituir a idade de Maria (64) pelo
valor 65
'''
df.idade[3] = 65
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
# <ipython-input-136-54817e6b636c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.idade[3] = 65
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     65    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# substituindo o valor de uma célula
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
'''
Imagine que você deseja substituir a idade de Maria (64) pelo
valor 65
'''
df.iat[3,1] = 65
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     65    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# substituindo o valor de uma célula
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
'''
Imagine que você deseja substituir a idade de Maria (64) pelo
valor 65
'''
df.at[3,'idade'] = 65
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     65    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# ordenando de forma crescente um dataframe de acordo com um atributo
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
df = df.sort_values('idade')
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade  altura  peso sexo
# 1  Daniela      7    1.23    22    F
# 5    Ester     37    1.73    68    F
# 4  Eduardo     42    1.82    96    M
# 0  Douglas     45    1.85    70    M
# 3    Maria     64    1.67    64    F
# 2    Pedro     65    1.75    87    M

# %%
# ordenando de forma decrescente um dataframe de acordo com um atributo
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
df = df.sort_values('idade',ascending=False)
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade  altura  peso sexo
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 0  Douglas     45    1.85    70    M
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
# 1  Daniela      7    1.23    22    F

# %%
'''
Exercício:
Crie um dataframe com as seguintes medidas descritivas a partir do
df original:
1 - contagem - (count)
2 - media - (mean)
3 - mediana - (criar linha nova)
4 - moda - (criar linha nova)
5 - variância - (criar linha nova)
6 - desvio padrão - (std)
7 - valor mínimo - (min)
8 - Q1 - (25%)
9 - Q2 - (50%)
10 -Q3 - (75%)
11 -Valor máximo (max)
12 -AIQ - (criar linha nova)
13 -LI - (criar linha nova)
14 -LS -(criar linha nova)
'''
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
medidas = df.describe()
mediana =[df.idade.median(),df.altura.median(),df.peso.median()]
moda =[[df.idade.mode()][0][0],[df.altura.mode()][0][0],[df.peso.mode()][0][0]]
variancia =[df.idade.var(),df.altura.var(),df.peso.var()]
q1 = list(medidas.loc['25%'])
q3 = list(medidas.loc['75%'])
aiq = []
for i in range(len(q1)):
  aiq.append(q3[i]-q1[i])
li = []
for i in range(len(q1)):
  li.append(q1[i]-1.5*aiq[i])
ls = []
for i in range(len(q3)):
  ls.append(q3[i]+1.5*aiq[i])
medidas.loc['mediana'] = mediana
medidas.loc['moda'] = moda
medidas.loc['variancia'] = variancia
medidas.loc['aiq'] = aiq
medidas.loc['li'] = li
medidas.loc['ls'] = ls
medidas = medidas.loc[['count','mean','mediana','moda','variancia','std',
                       'min','25%','50%','75%','max','aiq','li','ls']]
display(medidas)
medidas = medidas.rename({'count':'contagem',
                          'mean':'media','std':'desvio padrao',
                          'min':'valor minimo', '25%':'Q1','50%':'Q2','75%':'Q3',
                          'max': 'valor maximo'}, axis=0)
display(medidas)
# Out:
#                 idade   altura        peso
# count        6.000000  6.00000    6.000000
# mean        43.333333  1.67500   67.833333
# mediana     43.500000  1.74000   69.000000
# moda         7.000000  1.23000   22.000000
# variancia  452.266667  0.05167  656.166667
# std         21.266562  0.22731   25.615750
# min          7.000000  1.23000   22.000000
# 25%         38.250000  1.68500   65.000000
# 50%         43.500000  1.74000   69.000000
# 75%         59.250000  1.80250   82.750000
# max         65.000000  1.85000   96.000000
# aiq         21.000000  0.11750   17.750000
# li           6.750000  1.50875   38.375000
# ls          90.750000  1.97875  109.375000
#                     idade   altura        peso
# contagem         6.000000  6.00000    6.000000
# media           43.333333  1.67500   67.833333
# mediana         43.500000  1.74000   69.000000
# moda             7.000000  1.23000   22.000000
# variancia      452.266667  0.05167  656.166667
# desvio padrao   21.266562  0.22731   25.615750
# valor minimo     7.000000  1.23000   22.000000
# Q1              38.250000  1.68500   65.000000
# Q2              43.500000  1.74000   69.000000
# Q3              59.250000  1.80250   82.750000
# valor maximo    65.000000  1.85000   96.000000
# aiq             21.000000  0.11750   17.750000
# li               6.750000  1.50875   38.375000
# ls              90.750000  1.97875  109.375000

# %% [markdown]
# # Agrupamentos

# %%
import pandas as pd
nome = ['Douglas','Daniela','Douglas','Maria','Douglas','Ester']
dependentes = [1,0,2,2,2,3]
salario = [1500,9000,1500,8000,2000,5000]
cargo = ['analista','gerente','analista','gerente','analista','coordenadora']
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,dependentes,salario,cargo,sexo),
                  columns=['nome','dependentes','salario','cargo','sexo'])
display(df)
# Out:
#       nome  dependentes  salario         cargo sexo
# 0  Douglas            1     1500      analista    M
# 1  Daniela            0     9000       gerente    F
# 2  Douglas            2     1500      analista    M
# 3    Maria            2     8000       gerente    F
# 4  Douglas            2     2000      analista    M
# 5    Ester            3     5000  coordenadora    F

# %%
# Verificando os valores únicos de um atributo(distintos)
df.nome.unique()
# Out:
# array(['Douglas', 'Daniela', 'Maria', 'Ester'], dtype=object)

# %%
'''
Consulta que retorna o número de dependentes agrupado pr nomes
'''
df[['nome','dependentes']].groupby('nome').sum()
# Out:
#          dependentes
# nome
# Daniela            0
# Douglas            5
# Ester              3
# Maria              2

# %%
'''
Essa consulta seleciona nome e salario, agrupando os
resultados por nome e exibindo nomes únicos (distintos) e
suas respecitivas somas de salários
'''
df[['nome','salario']].groupby('nome').sum()
# Out:
#          salario
# nome
# Daniela     9000
# Douglas     5000
# Ester       5000
# Maria       8000

# %%
'''
Consulta que retorna nome e salário agrupando por nomes
e exibindo a média dos salários agrupados
'''
df[['nome','salario']].groupby('nome').mean()
# Out:
#              salario
# nome
# Daniela  9000.000000
# Douglas  1666.666667
# Ester    5000.000000
# Maria    8000.000000

# %%
'''
Selecionando as colunas cargo e salário e exibindo as medianas dos
salários agrupados por cargo
'''
df[['cargo','salario']].groupby('cargo').median()
# Out:
#               salario
# cargo
# analista       1500.0
# coordenadora   5000.0
# gerente        8500.0

# %%
'''
Selecionando as colunas cargo e salário e exibindo as médias dos
salários agrupados por cargo
'''
df[['cargo','salario']].groupby('cargo').mean()
# Out:
#                   salario
# cargo
# analista      1666.666667
# coordenadora  5000.000000
# gerente       8500.000000

# %%
'''
Selecionando as colunas cargo e salário e exibindo o Q1 (25%) dos
salários agrupados por cargo
'''
df[['cargo','salario']].groupby('cargo').quantile(0.99)
# Out:
#               salario
# cargo
# analista       1990.0
# coordenadora   5000.0
# gerente        8990.0

# %% [markdown]
# ## Criando novas colunas

# %%
'''
Imagine que a partir dos dados de peso e altura da base a seguir você deseja
criar uma nova coluna no df com o resultado do imc para cada registro
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
df['imc'] = round(df['peso']/df['altura'],2)
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade  altura  peso sexo    imc
# 0  Douglas     45    1.85    70    M  37.84
# 1  Daniela      7    1.23    22    F  17.89
# 2    Pedro     65    1.75    87    M  49.71
# 3    Maria     64    1.67    64    F  38.32
# 4  Eduardo     42    1.82    96    M  52.75
# 5    Ester     37    1.73    68    F  39.31

# %% [markdown]
# ## Inserindo uma linha de total em um DF

# %%
'''
Imagine que coê deseja criar uma linha com o total das colunas numéricas
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
df.loc[6] = ['Soma',df['idade'].sum(),df['altura'].sum(),df['peso'].sum(),'-']
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
# 6     Soma    260   10.05   407    -

# %% [markdown]
# # Fazendo filtros em um DF

# %%
'''
Filtrar somente os registros e seus atributos para os eleemntos com 40 anos
ou mais
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
filtro01 = df.loc[df['idade']>=40,['nome','idade']]
display(filtro01)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade
# 0  Douglas     45
# 2    Pedro     65
# 3    Maria     64
# 4  Eduardo     42

# %%
'''
Filtrar somente os registros e seus atributos para os eleemntos com 40 anos
ou mais usando o método query
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
filtro02 = df.query('idade >= 40')
filtro02 = filtro02[['nome','idade']]
display(filtro02)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade
# 0  Douglas     45
# 2    Pedro     65
# 3    Maria     64
# 4  Eduardo     42

# %%
'''
Filtrando colunas qualitativas usando o método query
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
display(df)
df.query('sexo == "M"')
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 2    Pedro     65    1.75    87    M
# 4  Eduardo     42    1.82    96    M

# %%
'''
Filtrando colunas com espaço no nome pelo método query
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade funcionario','altura','peso','sexo'])
display(df)
filtro03 = df.query('`idade funcionario` >= 40')
display(filtro03)
# Out:
#       nome  idade funcionario  altura  peso sexo
# 0  Douglas                 45    1.85    70    M
# 1  Daniela                  7    1.23    22    F
# 2    Pedro                 65    1.75    87    M
# 3    Maria                 64    1.67    64    F
# 4  Eduardo                 42    1.82    96    M
# 5    Ester                 37    1.73    68    F
#       nome  idade funcionario  altura  peso sexo
# 0  Douglas                 45    1.85    70    M
# 2    Pedro                 65    1.75    87    M
# 3    Maria                 64    1.67    64    F
# 4  Eduardo                 42    1.82    96    M

# %% [markdown]
# # Unindo dfs

# %%
'''
Filtrando colunas com espaço no nome pelo método query
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
display(df)
# Out:
#       nome  idade  altura  massa genero    imc
# 0  Douglas     45    1.85     70      M  20.45
# 1  Daniela      7    1.23     22      F  14.54
# 2    Pedro     65    1.75     87      M  28.41
# 3    Maria     64    1.67     64      F  22.95
# 4  Eduardo     42    1.82     96      M  28.98
# 5    Ester     37    1.73     68      F  22.72

# %%
df2 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRg09sDMtHT1fErHtoNumxvPsqvHpeChBW3JCLtvwCxHheP7qwC1ZuTQttAPC2lHlosGW9Ct3zdCULi/pub?gid=297665027&single=true&output=csv')
display(df2)
# Out:
#       nome  idade  altura  massa genero    imc
# 0  Joaquim     56    1.67     69      M  24.74
# 1   Aurora     34    1.55     53      F  22.06
# 2   Manoel     23    1.76     68      M  21.95

# %%
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
print('************** DF 01 - *****************')
display(df)
df2 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRg09sDMtHT1fErHtoNumxvPsqvHpeChBW3JCLtvwCxHheP7qwC1ZuTQttAPC2lHlosGW9Ct3zdCULi/pub?gid=297665027&single=true&output=csv')
print('************** DF 02 - *****************')
display(df2)
'''
agora queremos unir df e df2 e para isso vamos utilizar o método concat
'''
df3 = pd.concat([df,df2])
print('************** DF 03 - *****************')
display(df3)
'''
Observe que ao unir os dois dfs os índices de cada df foram preservados,
assim, vamos reorganizá-los
'''
df3 = df3.sort_values('nome')
df3.reset_index(drop=True, inplace=True)
print('************** DF 03 - *****************')
display(df3)
# Out:
# ************** DF 01 - *****************
#       nome  idade  altura  massa genero    imc
# 0  Douglas     45    1.85     70      M  20.45
# 1  Daniela      7    1.23     22      F  14.54
# 2    Pedro     65    1.75     87      M  28.41
# 3    Maria     64    1.67     64      F  22.95
# 4  Eduardo     42    1.82     96      M  28.98
# 5    Ester     37    1.73     68      F  22.72
# ************** DF 02 - *****************
#       nome  idade  altura  massa genero    imc
# 0  Joaquim     56    1.67     69      M  24.74
# 1   Aurora     34    1.55     53      F  22.06
# 2   Manoel     23    1.76     68      M  21.95
# ************** DF 03 - *****************
#       nome  idade  altura  massa genero    imc
# 0  Douglas     45    1.85     70      M  20.45
# 1  Daniela      7    1.23     22      F  14.54
# 2    Pedro     65    1.75     87      M  28.41
# 3    Maria     64    1.67     64      F  22.95
# 4  Eduardo     42    1.82     96      M  28.98
# 5    Ester     37    1.73     68      F  22.72
# 0  Joaquim     56    1.67     69      M  24.74
# 1   Aurora     34    1.55     53      F  22.06
# 2   Manoel     23    1.76     68      M  21.95
# ************** DF 03 - *****************
#       nome  idade  altura  massa genero    imc
# 0   Aurora     34    1.55     53      F  22.06
# 1  Daniela      7    1.23     22      F  14.54
# 2  Douglas     45    1.85     70      M  20.45
# 3  Eduardo     42    1.82     96      M  28.98
# 4    Ester     37    1.73     68      F  22.72
# 5  Joaquim     56    1.67     69      M  24.74
# 6   Manoel     23    1.76     68      M  21.95
# 7    Maria     64    1.67     64      F  22.95
# 8    Pedro     65    1.75     87      M  28.41

# %% [markdown]
# ## Substituindo valores de uma coluna

# %%
'''
Imagine que você deseja substituir todos os valores M da coluna genero,
por masculino e valores F por feminino
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
df['genero'] = df['genero'].map({'M':'masculino','F':'feminino'})
display(df)
# Out:
#       nome  idade  altura  massa     genero    imc
# 0  Douglas     45    1.85     70  masculino  20.45
# 1  Daniela      7    1.23     22   feminino  14.54
# 2    Pedro     65    1.75     87  masculino  28.41
# 3    Maria     64    1.67     64   feminino  22.95
# 4  Eduardo     42    1.82     96  masculino  28.98
# 5    Ester     37    1.73     68   feminino  22.72

# %%
'''
Imagine que você deseja substituir todos os valores M da coluna genero,
por 0 e valores F por 1
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
df['genero'] = df['genero'].map({'M':0,'F':1})
display(df)
# Out:
#       nome  idade  altura  massa  genero    imc
# 0  Douglas     45    1.85     70       0  20.45
# 1  Daniela      7    1.23     22       1  14.54
# 2    Pedro     65    1.75     87       0  28.41
# 3    Maria     64    1.67     64       1  22.95
# 4  Eduardo     42    1.82     96       0  28.98
# 5    Ester     37    1.73     68       1  22.72

# %% [markdown]
# ## Agrupando variáveis quantitativas

# %%
'''
Vamos supoe que desejamos crirar um nova coluna com as faixas etárias a partir
dos registros de idade, por exemplo: nessa nova coluna um regitro cuja idade
fosse 42 anos ficaria classificado em uma faixa etária de 41 a 50 anos por
exemplo
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
print('************** DF 01 - *****************')
display(df)
faixas = ['01 a 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 -70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
'''
O método cut, exige três argumentos:
1 - x: a coluna do df orginal que será usada como referência para criar a nova
2 - bins: uma lista com os valores que serão utilizado na variável x como ponto
de corte para a classificação das faixas
3 - labels: uma lista que contém todos os possíveis valores da nova coluna
'''
print('************** DF 01 - Trannsformado *****************')
display(df)
# Out:
# ************** DF 01 - *****************
#       nome  idade  altura  massa genero    imc
# 0  Douglas     45    1.85     70      M  20.45
# 1  Daniela      7    1.23     22      F  14.54
# 2    Pedro     65    1.75     87      M  28.41
# 3    Maria     64    1.67     64      F  22.95
# 4  Eduardo     42    1.82     96      M  28.98
# 5    Ester     37    1.73     68      F  22.72
# ************** DF 01 - Trannsformado *****************
#       nome  idade  altura  massa genero    imc faixa_etaria
# 0  Douglas     45    1.85     70      M  20.45      41 - 50
# 1  Daniela      7    1.23     22      F  14.54      01 a 10
# 2    Pedro     65    1.75     87      M  28.41       61 -70
# 3    Maria     64    1.67     64      F  22.95       61 -70
# 4  Eduardo     42    1.82     96      M  28.98      41 - 50
# 5    Ester     37    1.73     68      F  22.72      31 - 40

# %% [markdown]
# ## Inserindo nova coluna em uma posição específica

# %%
'''
Imagine que você deseja inserir uma nova coluna com os cargos
dos funcionários, mas deseja que essa nova coluna fique posicionada
imediatamente após a coluna nome, sem excluir as demais colunas, ou seja,
"empurrando" as colunas para frente
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
print('************** DF 01 - *****************')
display(df)
df.insert(1,'cargo', ['analista','gerente','coordenador','analista','gerente',
                      'diretor'])
print('************** DF 01 - com cargo *****************')
display(df)
# Out:
# ************** DF 01 - *****************
#       nome  idade  altura  massa genero    imc
# 0  Douglas     45    1.85     70      M  20.45
# 1  Daniela      7    1.23     22      F  14.54
# 2    Pedro     65    1.75     87      M  28.41
# 3    Maria     64    1.67     64      F  22.95
# 4  Eduardo     42    1.82     96      M  28.98
# 5    Ester     37    1.73     68      F  22.72
# ************** DF 01 - com cargo *****************
#       nome        cargo  idade  altura  massa genero    imc
# 0  Douglas     analista     45    1.85     70      M  20.45
# 1  Daniela      gerente      7    1.23     22      F  14.54
# 2    Pedro  coordenador     65    1.75     87      M  28.41
# 3    Maria     analista     64    1.67     64      F  22.95
# 4  Eduardo      gerente     42    1.82     96      M  28.98
# 5    Ester      diretor     37    1.73     68      F  22.72

# %% [markdown]
# ## Convertendo dados de um atributo

# %%
'''
Imagine que você deseja converter os valores da coluna massa
que originalmentes estão como tipo int em tipo float
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
print('************** DF 01 - com massa tipo int *****************')
print(df.dtypes)
df['massa'] = df['massa'].astype('float')
print('************** DF 01 - com massa tipo float *****************')
print(df.dtypes)

# %% [markdown]
# ## Reordenando a posição das colunas em um dataframe

# %%
'''
Imagine que você deseja converter os valores da coluna massa
que originalmentes estão como tipo int em tipo float
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
print('************** DF 01 - posição original *****************')
display(df)
'''
vamos supor que desejamos colocar imc antes de genero
'''
df = df[['nome','idade','altura','massa','imc','genero']]
print('************** DF 01 - posição reordenada *****************')
display(df)

# %% [markdown]
# # Criando distribuições de frequência

# %%
'''
Imagine que você deseja criar uma distribuição de frequência para o
atributo faixa etária
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 a 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 -70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
'''
O método cut, exige três argumentos:
1 - x: a coluna do df orginal que será usada como referência para criar a nova
2 - bins: uma lista com os valores que serão utilizado na variável x como ponto
de corte para a classificação das faixas
3 - labels: uma lista que contém todos os possíveis valores da nova coluna
'''
print('************** DF 01 - Trannsformado *****************')
display(df)
df.groupby('faixa_etaria')['faixa_etaria'].count()
# Out:
# ************** DF 01 - Trannsformado *****************
#       nome  idade  altura  massa genero    imc faixa_etaria
# 0  Douglas     45    1.85     70      M  20.45      41 - 50
# 1  Daniela      7    1.23     22      F  14.54      01 a 10
# 2    Pedro     65    1.75     87      M  28.41       61 -70
# 3    Maria     64    1.67     64      F  22.95       61 -70
# 4  Eduardo     42    1.82     96      M  28.98      41 - 50
# 5    Ester     37    1.73     68      F  22.72      31 - 40
# faixa_etaria
# 01 a 10    1
# 11 - 20    0
# 21 - 30    0
# 31 - 40    1
# 41 - 50    2
# 51 - 60    0
# 61 -70     2
# Name: faixa_etaria, dtype: int64

# %%
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
df
# Out:
#       nome  idade  altura  massa genero    imc faixa_etaria
# 0  Douglas     45    1.85     70      M  20.45      41 - 50
# 1  Daniela      7    1.23     22      F  14.54      01 - 10
# 2    Pedro     65    1.75     87      M  28.41      61 - 70
# 3    Maria     64    1.67     64      F  22.95      61 - 70
# 4  Eduardo     42    1.82     96      M  28.98      41 - 50
# 5    Ester     37    1.73     68      F  22.72      31 - 40

# %%
tabela = df.groupby('faixa_etaria')['faixa_etaria'].count()
tabela
# Out:
# faixa_etaria
# 01 - 10    1
# 11 - 20    1
# 21 - 30    1
# 31 - 40    1
# 41 - 50    1
# 51 - 60    1
# 61 - 70    1
# Name: faixa_etaria, dtype: int64

# %%
'''
No bloco anterior, ao aplicar o groupby nós geramos um objeto que possui uma única
dimensão, mesmo mostrando " duas colunas", assim, se nosso objetivo for guardar
essas frequências em uma tabela, devemos fazer o seguinte:
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester','Zé']
idade = [45,7,65,54,25,37,16]
altura = [1.85,1.23,1.75,1.67,1.82,1.73,1.68]
peso = [70,22,87,64,96,68,70]
sexo = ['M','F','M','F','M','F','M']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
'''
1 - gerar uma lista com os valores únicos da variável que estamos contando e
armazená-la em uma variável
'''
xpto = df['faixa_etaria'].unique()

'''
2 - Realizar o groupby e armazená-lo em uma variável
'''
freq = df.groupby('faixa_etaria')['faixa_etaria'].count()

'''
3 - Criar um dataframe com as duas variáveis armazenadas anteriormente
'''
df3 = pd.DataFrame(zip(xpto,freq),columns=['Faixa Etária','Frequência'])
display(df3)
df3 = df3.sort_values(by='Faixa Etária')
display(df3)
'''
Nesse processo temo um PROBLEMA:
ao gerar um objeto pelo .unique() teremos uma lista só com os valores únicos
que aparecem na variável faixa etária.
No entanto quando geramos o segundo objeto pelo .groupby podemos ter uma lista
maior que a lista gerada pelo unique, pois o .groupby contará também as categorias
listadas cuja frequencia for 0 , ou seja, aqueles que não aparecerão na lista do
.unique, e como resultado teremos duas listas que terão tamanhos diferentes
e ao usarmos o .pd.DataFrame a união será feita com base na lista de menos elementos
'''
# Out:
#   Faixa Etária  Frequência
# 0      41 - 50           1
# 1      01 - 10           1
# 2      61 - 70           1
# 3      51 - 60           1
# 4      21 - 30           1
# 5      31 - 40           1
# 6      11 - 20           1
#   Faixa Etária  Frequência
# 1      01 - 10           1
# 6      11 - 20           1
# 4      21 - 30           1
# 5      31 - 40           1
# 0      41 - 50           1
# 3      51 - 60           1
# 2      61 - 70           1

# %%
'''
Exercício:
faça o mesmo procedimento do exercício anterior para a variável genero
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
'''
1 - gerar uma lista com os valores únicos da variável que estamos contando e
armazená-la em uma variável
'''
gender = df['genero'].unique()

'''
2 - Realizar o groupby e armazená-lo em uma variável
'''
freq = df.groupby('genero')['genero'].count()

'''
3 - Criar um dataframe com as duas variáveis armazenadas anteriormente
'''
df4 = pd.DataFrame(zip(gender,freq),columns=['Gênero','Frequência'])
display(df4)
df4 = df4.sort_values(by='Gênero')
display(df4)
# Out:
#   Gênero  Frequência
# 0      M           3
# 1      F           3
#   Gênero  Frequência
# 1      F           3
# 0      M           3

# %%
'''
Exercício:
faça o mesmo procedimento do exercício anterior para a variável nome
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
'''
1 - gerar uma lista com os valores únicos da variável que estamos contando e
armazená-la em uma variável
'''
gender = df['nome'].unique()

'''
2 - Realizar o groupby e armazená-lo em uma variável
'''
freq = df.groupby('nome')['nome'].count()

'''
3 - Criar um dataframe com as duas variáveis armazenadas anteriormente
'''
df5 = pd.DataFrame(zip(gender,freq),columns=['Nome','Frequência'])
display(df5)
df5 = df5.sort_values(by='Nome')
display(df5)
# Out:
#       Nome  Frequência
# 0  Douglas           1
# 1  Daniela           1
# 2    Pedro           1
# 3    Maria           1
# 4  Eduardo           1
# 5    Ester           1
#       Nome  Frequência
# 1  Daniela           1
# 0  Douglas           1
# 4  Eduardo           1
# 5    Ester           1
# 3    Maria           1
# 2    Pedro           1

# %%
'''
Agora vamos ver um método para criar a columa de frequência percentual
tendo como referência a coluna frequência
'''

import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
'''
1 - gerar uma lista com os valores únicos da variável que estamos contando e
armazená-la em uma variável
'''
gender = df['nome'].unique()

'''
2 - Realizar o groupby e armazená-lo em uma variável
'''
freq = df.groupby('nome')['nome'].count()

'''
3 - Criar um dataframe com as duas variáveis armazenadas anteriormente
'''

'''
4 - Criar a coluna de frquencia percentual
'''

df5 = pd.DataFrame(zip(gender,freq),columns=['Nome','Frequência'])
#display(df5)
df5 = df5.sort_values(by='Nome')
#display(df5)
df5['Frequência %'] = round((df5['Frequência']/df5['Frequência'].sum())*100,2)
df5
# Out:
#       Nome  Frequência  Frequência %
# 1  Daniela           1         16.67
# 0  Douglas           1         16.67
# 4  Eduardo           1         16.67
# 5    Ester           1         16.67
# 3    Maria           1         16.67
# 2    Pedro           1         16.67

# %%
'''
Calculando a freuência percentual para a variável gênero
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
'''
1 - gerar uma lista com os valores únicos da variável que estamos contando e
armazená-la em uma variável
'''
gender = df['genero'].unique()

'''
2 - Realizar o groupby e armazená-lo em uma variável
'''
freq = df.groupby('genero')['genero'].count()

'''
3 - Criar um dataframe com as duas variáveis armazenadas anteriormente
'''
df6 = pd.DataFrame(zip(gender,freq),columns=['Gênero','Frequência'])
df6 = df6.sort_values(by='Gênero')
df6['Frequência %'] = round((df6['Frequência']/df6['Frequência'].sum())*100,2)
df6.loc[2] = ['Total',df6['Frequência'].sum(),df6['Frequência %'].sum()]
df6
# Out:
#   Gênero  Frequência  Frequência %
# 1      F           3          50.0
# 0      M           3          50.0
# 2  Total           6         100.0

# %%
'''
Exercício:
faça o mesmo procedimento do exercício anterior para a variável faixa etária
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester','Zé']
idade = [45,7,65,54,25,37,16]
altura = [1.85,1.23,1.75,1.67,1.82,1.73,1.68]
peso = [70,22,87,64,96,68,70]
sexo = ['M','F','M','F','M','F','M']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
'''
1 - gerar uma lista com os valores únicos da variável que estamos contando e
armazená-la em uma variável
'''
xpto = df['faixa_etaria'].unique()

'''
2 - Realizar o groupby e armazená-lo em uma variável
'''
freq = df.groupby('faixa_etaria')['faixa_etaria'].count()

'''
3 - Criar um dataframe com as duas variáveis armazenadas anteriormente
'''
df7 = pd.DataFrame(zip(xpto,freq),columns=['Faixa Etária','Frequência'])
display(df7)
df7 = df7.sort_values(by='Faixa Etária')
display(df7)
df7['Frequência %'] = round((df7['Frequência']/df7['Frequência'].sum())*100,2)
df7.loc[7] = ['Total',df7['Frequência'].sum(),df7['Frequência %'].sum()]
display(df7)
# Out:
#   Faixa Etária  Frequência
# 0      41 - 50           1
# 1      01 - 10           1
# 2      61 - 70           1
# 3      51 - 60           1
# 4      21 - 30           1
# 5      31 - 40           1
# 6      11 - 20           1
#   Faixa Etária  Frequência
# 1      01 - 10           1
# 6      11 - 20           1
# 4      21 - 30           1
# 5      31 - 40           1
# 0      41 - 50           1
# 3      51 - 60           1
# 2      61 - 70           1
#   Faixa Etária  Frequência  Frequência %
# 1      01 - 10           1         14.29
# 6      11 - 20           1         14.29
# 4      21 - 30           1         14.29
# 5      31 - 40           1         14.29
# 0      41 - 50           1         14.29
# 3      51 - 60           1         14.29
# 2      61 - 70           1         14.29
# 7        Total           7        100.03

# %%
'''
Recapitulando o problema do uso do groupby para criar distribuições de
frequências para variáveis quantitativas
'''

'''
Nesse processo temo um PROBLEMA:
ao gerar um objeto pelo .unique() teremos uma lista só com os valores únicos
que aparecem na variável faixa etária.
No entanto quando geramos o segundo objeto pelo .groupby podemos ter uma lista
maior que a lista gerada pelo unique, pois o .groupby contará também as categorias
listadas cuja frequencia for 0 , ou seja, aqueles que não aparecerão na lista do
.unique, e como resultado teremos duas listas que terão tamanhos diferentes
e ao usarmos o .pd.DataFrame a união será feita com base na lista de menos elementos
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
freq = df['faixa_etaria'].value_counts()
display(freq)
percentual = df['faixa_etaria'].value_counts(normalize=True)*100
display(percentual)
# Out:
# faixa_etaria
# 41 - 50    2
# 61 - 70    2
# 01 - 10    1
# 31 - 40    1
# 11 - 20    0
# 21 - 30    0
# 51 - 60    0
# Name: count, dtype: int64
# faixa_etaria
# 41 - 50    33.333333
# 61 - 70    33.333333
# 01 - 10    16.666667
# 31 - 40    16.666667
# 11 - 20     0.000000
# 21 - 30     0.000000
# 51 - 60     0.000000
# Name: proportion, dtype: float64

# %%
'''
Vamos criar a frequência percentual para a variável gênero pelo método
value_counts
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
freq = df['genero'].value_counts()
percentual = df['genero'].value_counts(normalize=True)*100
generos = pd.DataFrame({'Frequência Absoluta':freq,'Frequência Percentual':percentual})
generos.reset_index(inplace=True)
generos.loc[2] = ['TOTAL',generos['Frequência Absoluta'].sum(),
                  generos['Frequência Percentual'].sum()]
display(generos)
# Out:
#   genero  Frequência Absoluta  Frequência Percentual
# 0      M                    3                   50.0
# 1      F                    3                   50.0
# 2  TOTAL                    6                  100.0

# %%
'''
Vamos criar a frequência percentual para a variável nome pelo método
value_counts
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
freq = df['nome'].value_counts() # aqui estamos criando um objeto com a contagem de todos os valores únicos da variável de interesse
percentual = df['nome'].value_counts(normalize=True)*100 # aqui estamos criando um objeto com a contagem percentual de todos os valores únicos da variável de interesse
nomes = pd.DataFrame({'Frequência Absoluta':freq,'Frequência Percentual':percentual}) # aqui estamos criando um dataframe com os dois objetos criados anteiormente
nomes.reset_index(inplace=True)
nomes.loc[6] = ['TOTAL',nomes['Frequência Absoluta'].sum(),
                  nomes['Frequência Percentual'].sum()] # Aqui estamos inserindo uma linha de total na tabela de frequências
display(nomes)
# Out:
#       nome  Frequência Absoluta  Frequência Percentual
# 0  Douglas                    1              16.666667
# 1  Daniela                    1              16.666667
# 2    Pedro                    1              16.666667
# 3    Maria                    1              16.666667
# 4  Eduardo                    1              16.666667
# 5    Ester                    1              16.666667
# 6    TOTAL                    6             100.000000

# %%
'''
Vamos criar a frequência percentual para a variável faixa etária pelo método
value_counts
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
freq = df['faixa_etaria'].value_counts() # aqui estamos criando um objeto com a contagem de todos os valores únicos da variável de interesse
percentual = df['faixa_etaria'].value_counts(normalize=True)*100 # aqui estamos criando um objeto com a contagem percentual de todos os valores únicos da variável de interesse
idades = pd.DataFrame({'Frequência Absoluta':freq,'Frequência Percentual':percentual}) # aqui estamos criando um dataframe com os dois objetos criados anteiormente
idades = idades.sort_values(by='faixa_etaria')
idades.reset_index(inplace=True)

'''
Quando temos uma variavél quantitativa a distribuição de frequência deve ter
duas colunas a mais:
1 - Frequencia acumulada
2 - Frequencia acumulada %
'''
idades['Frequência Acumulada'] = idades['Frequência Absoluta'].cumsum() # Esta linha cria a coluna de frequencia acumulada
idades['Frequência Acumulada %'] = (idades['Frequência Acumulada']/idades['Frequência Absoluta'].sum())*100 # Esta linha cria a coluna de frequencia acumulada %

idades.loc[7] = ['TOTAL',idades['Frequência Absoluta'].sum(),
                  idades['Frequência Percentual'].sum(),'-','-'] # Aqui estamos inserindo uma linha de total na tabela de frequências
display(idades)
# Out:
#   faixa_etaria  Frequência Absoluta  Frequência Percentual  \
# 0      01 - 10                    1              16.666667
# 1      11 - 20                    0               0.000000
# 2      21 - 30                    0               0.000000
# 3      31 - 40                    1              16.666667
# 4      41 - 50                    2              33.333333
# 5      51 - 60                    0               0.000000
# 6      61 - 70                    2              33.333333
# 7        TOTAL                    6             100.000000
#
#   Frequência Acumulada Frequência Acumulada %
# 0                    1              16.666667
# 1                    1              16.666667
# 2                    1              16.666667
# 3                    2              33.333333
# 4                    4              66.666667
# 5                    4              66.666667
# 6                    6                  100.0
# 7                    -                      -

# %%
'''
considerando a base de dados a segui, construa as distribuções de frequências
adequadas para cada tipo de variável, no caso da variável faturamento
no pandas construa uma nova coluna classificado o faturamento por faixas
sendo as seguintes faixas:
[10001 - 12000, 12001 - 14000, 14001 - 16000, 16001 - 18000, 18001 - 20000]
'''
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTFGertCc67cL9ojU5rRq8qyCBojGKrH7m2zU7hqYJ1AKRm-oBpTNjRhGztmhYrzJApq3-FNbx0EPz3/pub?gid=0&single=true&output=csv')
display(df)

# %% [markdown]
# ## Gabarito do exercício

# %%
import pandas as pd
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTFGertCc67cL9ojU5rRq8qyCBojGKrH7m2zU7hqYJ1AKRm-oBpTNjRhGztmhYrzJApq3-FNbx0EPz3/pub?gid=0&single=true&output=csv')
freq = df['genero'].value_counts() # aqui estamos criando um objeto com a contagem de todos os valores únicos da variável de interesse
percentual = df['genero'].value_counts(normalize=True)*100 # aqui estamos criando um objeto com a contagem percentual de todos os valores únicos da variável de interesse
generos = pd.DataFrame({'Frequência Absoluta':freq,'Frequência Percentual':percentual}) # aqui estamos criando um dataframe com os dois objetos criados anteiormente
generos.reset_index(inplace=True)
generos.loc[2] = ['TOTAL',generos['Frequência Absoluta'].sum(),
                  generos['Frequência Percentual'].sum()] # Aqui estamos inserindo uma linha de total na tabela de frequências
display(generos)
# Out:
#   genero  Frequência Absoluta  Frequência Percentual
# 0      f                   11                   55.0
# 1      m                    9                   45.0
# 2  TOTAL                   20                  100.0

# %%
import pandas as pd
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTFGertCc67cL9ojU5rRq8qyCBojGKrH7m2zU7hqYJ1AKRm-oBpTNjRhGztmhYrzJApq3-FNbx0EPz3/pub?gid=0&single=true&output=csv')
freq = df['departamento'].value_counts() # aqui estamos criando um objeto com a contagem de todos os valores únicos da variável de interesse
percentual = df['departamento'].value_counts(normalize=True)*100 # aqui estamos criando um objeto com a contagem percentual de todos os valores únicos da variável de interesse
departamentos = pd.DataFrame({'Frequência Absoluta':freq,'Frequência Percentual':percentual}) # aqui estamos criando um dataframe com os dois objetos criados anteiormente
departamentos.reset_index(inplace=True)
departamentos.loc[3] = ['TOTAL',departamentos['Frequência Absoluta'].sum(),
                  departamentos['Frequência Percentual'].sum()] # Aqui estamos inserindo uma linha de total na tabela de frequências
display(departamentos)
# Out:
#   departamento  Frequência Absoluta  Frequência Percentual
# 0       eletro                    8                   40.0
# 1           ud                    6                   30.0
# 2         info                    6                   30.0
# 3        TOTAL                   20                  100.0

# %%
import pandas as pd
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTFGertCc67cL9ojU5rRq8qyCBojGKrH7m2zU7hqYJ1AKRm-oBpTNjRhGztmhYrzJApq3-FNbx0EPz3/pub?gid=0&single=true&output=csv')
freq = df['uf'].value_counts() # aqui estamos criando um objeto com a contagem de todos os valores únicos da variável de interesse
percentual = df['uf'].value_counts(normalize=True)*100 # aqui estamos criando um objeto com a contagem percentual de todos os valores únicos da variável de interesse
ufs = pd.DataFrame({'Frequência Absoluta':freq,'Frequência Percentual':percentual}) # aqui estamos criando um dataframe com os dois objetos criados anteiormente
ufs.reset_index(inplace=True)
ufs.loc[11] = ['TOTAL',ufs['Frequência Absoluta'].sum(),
                  ufs['Frequência Percentual'].sum()] # Aqui estamos inserindo uma linha de total na tabela de frequências
display(ufs)
# Out:
#        uf  Frequência Absoluta  Frequência Percentual
# 0      sp                    6                   30.0
# 1      mg                    3                   15.0
# 2      ba                    3                   15.0
# 3      rj                    1                    5.0
# 4      ce                    1                    5.0
# 5      al                    1                    5.0
# 6      pe                    1                    5.0
# 7      sc                    1                    5.0
# 8      rs                    1                    5.0
# 9      pr                    1                    5.0
# 10     es                    1                    5.0
# 11  TOTAL                   20                  100.0

# %%
'''
Código para contar a quantidade de opções únicas de um atributo
'''
est = df['uf'].unique()
len(est)
# Out:
# 11

# %%
import pandas as pd
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTFGertCc67cL9ojU5rRq8qyCBojGKrH7m2zU7hqYJ1AKRm-oBpTNjRhGztmhYrzJApq3-FNbx0EPz3/pub?gid=0&single=true&output=csv')
faixas = ['10001 - 12000', '12001 - 14000', '14001 - 16000', '16001 - 18000', '18001 - 20000']
df['faturamentos'] = pd.cut(x=df['faturamento'],bins=[10000,12000,14000,16000,18000,20000],labels=faixas)
freq = df['faturamentos'].value_counts() # aqui estamos criando um objeto com a contagem de todos os valores únicos da variável de interesse
percentual = df['faturamentos'].value_counts(normalize=True)*100 # aqui estamos criando um objeto com a contagem percentual de todos os valores únicos da variável de interesse
fatur = pd.DataFrame({'Frequência Absoluta':freq,'Frequência Percentual':percentual}) # aqui estamos criando um dataframe com os dois objetos criados anteiormente
fatur = fatur.sort_values(by='faturamentos')
fatur.reset_index(inplace=True)

'''
Quando temos uma variavél quantitativa a distribuição de frequência deve ter
duas colunas a mais:
1 - Frequencia acumulada
2 - Frequencia acumulada %
'''
fatur['Frequência Acumulada'] = fatur['Frequência Absoluta'].cumsum() # Esta linha cria a coluna de frequencia acumulada
fatur['Frequência Acumulada %'] = (fatur['Frequência Acumulada']/fatur['Frequência Absoluta'].sum())*100 # Esta linha cria a coluna de frequencia acumulada %

fatur.loc[5] = ['TOTAL',fatur['Frequência Absoluta'].sum(),
                  fatur['Frequência Percentual'].sum(),'-','-'] # Aqui estamos inserindo uma linha de total na tabela de frequências
display(fatur)
# Out:
#     faturamentos  Frequência Absoluta  Frequência Percentual  \
# 0  10001 - 12000                    3                   15.0
# 1  12001 - 14000                    4                   20.0
# 2  14001 - 16000                    2                   10.0
# 3  16001 - 18000                    5                   25.0
# 4  18001 - 20000                    6                   30.0
# 5          TOTAL                   20                  100.0
#
#   Frequência Acumulada Frequência Acumulada %
# 0                    3                   15.0
# 1                    7                   35.0
# 2                    9                   45.0
# 3                   14                   70.0
# 4                   20                  100.0
# 5                    -                      -

# %% [markdown]
# ## Operações Especiais com Groupby - 29/04/2024

# %%
import pandas as pd
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTFGertCc67cL9ojU5rRq8qyCBojGKrH7m2zU7hqYJ1AKRm-oBpTNjRhGztmhYrzJApq3-FNbx0EPz3/pub?gid=0&single=true&output=csv')
group = df.groupby('departamento')

# %%
group = df.groupby('departamento')['faturamento']

# %%
group.mean()
# Out:
# departamento
# eletro    14511.625000
# info      17443.666667
# ud        15603.333333
# Name: faturamento, dtype: float64

# %%
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
df
# Out:
#       nome  idade  altura  massa genero    imc faixa_etaria
# 0  Douglas     45    1.85     70      M  20.45      41 - 50
# 1  Daniela      7    1.23     22      F  14.54      01 - 10
# 2    Pedro     65    1.75     87      M  28.41      61 - 70
# 3    Maria     64    1.67     64      F  22.95      61 - 70
# 4  Eduardo     42    1.82     96      M  28.98      41 - 50
# 5    Ester     37    1.73     68      F  22.72      31 - 40

# %%
agrupamento = df.groupby('genero')[['massa','altura','idade']]
display(agrupamento)

# %%
agrupamento.mean()
# Out:
#             massa    altura      idade
# genero
# F       51.333333  1.543333  36.000000
# M       84.333333  1.806667  50.666667

# %%
agrupamento.count()
# Out:
#         massa  altura  idade
# genero
# F           3       3      3
# M           3       3      3

# %%
'''
Utilizando o conceito de agrupamento faça uma distribuição de frequência das
faixas etárias
'''
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])
df['imc'] = round(df['peso']/df['altura']**2,2)
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
faixas = ['01 - 10','11 - 20','21 - 30','31 - 40','41 - 50','51 - 60','61 - 70']
df['faixa_etaria'] = pd.cut(x=df['idade'],bins=[0,10,20,30,40,50,60,70],labels=faixas)
idades = df.groupby('faixa_etaria')['idade']
idades.count()
# Out:
# faixa_etaria
# 01 - 10    1
# 11 - 20    0
# 21 - 30    0
# 31 - 40    1
# 41 - 50    2
# 51 - 60    0
# 61 - 70    2
# Name: idade, dtype: int64

# %%
'''
agora imagine que você deseja saber a idade mínima de cada grupo, masculino e
feminino
'''
agrupamento.min()
# Out:
#         massa  altura  idade
# genero
# F          22    1.23      7
# M          70    1.75     42

# %%
'''
Imagine que você deseja saber qual é o valor que separa os 25% menores dos 75%
maiores valores para as colunas massa, genero e idade
'''
'''
nesse caso nosso objetivo é encontrar o primeiro quartil desses atributos,
agrupados por gêneros
'''
agrupamento.quantile(0.25)
# Out:
#         massa  altura  idade
# genero
# F        43.0   1.450   22.0
# M        78.5   1.785   43.5

# %%
'''
Imagine que você deseja saber qual é o valor que separa os 50% menores dos 50%
maiores valores para as colunas massa, genero e idade
'''
'''
nesse caso nosso objetivo é encontrar o primeiro quartil desses atributos,
agrupados por gêneros
'''
agrupamento.quantile(0.5)
# Out:
#         massa  altura  idade
# genero
# F        64.0    1.67   37.0
# M        87.0    1.82   45.0

# %%
'''
Imagine que você deseja saber qual é o valor que separa os 50% menores dos 50%
maiores valores para as colunas massa, genero e idade
'''
'''
nesse caso nosso objetivo é encontrar o primeiro quartil desses atributos,
agrupados por gêneros
'''
agrupamento.median()
# Out:
#         massa  altura  idade
# genero
# F        64.0    1.67   37.0
# M        87.0    1.82   45.0

# %%
'''
Imagine que você deseja saber qual é o valor que separa os 75% menores dos 25%
maiores valores para as colunas massa, genero e idade
'''
'''
nesse caso nosso objetivo é encontrar o primeiro quartil desses atributos,
agrupados por gêneros
'''
agrupamento.quantile(0.75)
# Out:
#         massa  altura  idade
# genero
# F        66.0   1.700   50.5
# M        91.5   1.835   55.0

# %%
import pandas as pd
nome = ['Douglas','Daniela','Douglas','Maria','Douglas','Ester','Douglas','Ana',
        'Douglas','Juliana','Celia']
idades = [21, 25, 30, 35, 35, 40, 41, 42, 43, 45, 52]
dependentes = [1,0,2,2,2,3,1,2,0,4,2]
salario = [1500,9000,1500,8000,2000,5000,2000,7000,3500,9000,11000]
cargo = ['analista','gerente','analista','gerente','analista','coordenadora',
         'analista','coordenadora','analista','diretora','diretora']
sexo = ['M','F','M','F','M','F','M','F','M','F','F']
df = pd.DataFrame(zip(nome,idades,dependentes,salario,cargo,sexo),
                  columns=['nome','idades','dependentes','salario','cargo','sexo'])
df
# Out:
#        nome  idades  dependentes  salario         cargo sexo
# 0   Douglas      21            1     1500      analista    M
# 1   Daniela      25            0     9000       gerente    F
# 2   Douglas      30            2     1500      analista    M
# 3     Maria      35            2     8000       gerente    F
# 4   Douglas      35            2     2000      analista    M
# 5     Ester      40            3     5000  coordenadora    F
# 6   Douglas      41            1     2000      analista    M
# 7       Ana      42            2     7000  coordenadora    F
# 8   Douglas      43            0     3500      analista    M
# 9   Juliana      45            4     9000      diretora    F
# 10    Celia      52            2    11000      diretora    F

# %%
cargos = df.groupby('cargo')[['idades','salario']]

# %%
'''
Neste bloco temos a média de idades e salário agrupada por cargo
'''
cargos.mean()
# Out:
#               idades  salario
# cargo
# analista        34.0   2100.0
# coordenadora    41.0   6000.0
# diretora        48.5  10000.0
# gerente         30.0   8500.0

# %%
'''
Neste bloco temos a mediana de idades e salário agrupada por cargo
'''
cargos.median()
# Out:
#               idades  salario
# cargo
# analista        35.0   2000.0
# coordenadora    41.0   6000.0
# diretora        48.5  10000.0
# gerente         30.0   8500.0

# %%
idades_cargos = df.groupby('cargo')[['idades']]

# %%
idades_cargos.describe()
# Out:
#              idades
#               count  mean       std   min    25%   50%    75%   max
# cargo
# analista        5.0  34.0  8.888194  21.0  30.00  35.0  41.00  43.0
# coordenadora    2.0  41.0  1.414214  40.0  40.50  41.0  41.50  42.0
# diretora        2.0  48.5  4.949747  45.0  46.75  48.5  50.25  52.0
# gerente         2.0  30.0  7.071068  25.0  27.50  30.0  32.50  35.0

# %%
'''
Imagine que você deseja calcular as medidas descritivas agrupadas por cargos
tanto do atributo idades como do atributo salario
'''
idades_salarios_cargos = df.groupby('cargo')[['idades','salario']]
idades_salarios_cargos.describe()
# Out:
#              idades                                                 salario  \
#               count  mean       std   min    25%   50%    75%   max   count
# cargo
# analista        5.0  34.0  8.888194  21.0  30.00  35.0  41.00  43.0     5.0
# coordenadora    2.0  41.0  1.414214  40.0  40.50  41.0  41.50  42.0     2.0
# diretora        2.0  48.5  4.949747  45.0  46.75  48.5  50.25  52.0     2.0
# gerente         2.0  30.0  7.071068  25.0  27.50  30.0  32.50  35.0     2.0
#
#
#                  mean          std     min     25%      50%      75%      max
# cargo
# analista       2100.0   821.583836  1500.0  1500.0   2000.0   2000.0   3500.0
# coordenadora   6000.0  1414.213562  5000.0  5500.0   6000.0   6500.0   7000.0
# diretora      10000.0  1414.213562  9000.0  9500.0  10000.0  10500.0  11000.0
# gerente        8500.0   707.106781  8000.0  8250.0   8500.0   8750.0   9000.0

# %%
import pandas as pd
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])

# %% [markdown]
# ## Atualização 03/05/2024

# %%
import pandas as pd

# %%
'''
Atualização 03/05/2024
'''
'''
Utilizando o conceito de agrupamento faça uma distribuição de frequência das
faixas etárias
'''
faixas = ['00 - 10','11 - 20','21 - 30','31 - 40']
df['faixa'] = pd.cut(x=df['Total de anos trabalhados'],bins=[-1,10,20,30,40],labels=faixas)# quando a variável for quanti inteira os bins são excludentes, contam um a mais do que o informado, exemplo se tem 0 coloque o bin anterior(-1) para que o zero seja contado
idades = df.groupby('faixa')['Total de anos trabalhados']
idades.count()
# Out:
# faixa
# 00 - 10    923
# 11 - 20    340
# 21 - 30    161
# 31 - 40     46
# Name: Total de anos trabalhados, dtype: int64

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRvUmZWGvFp6i7t7pul-Ty44jNEz9dykaC99PDvWDu3LL5Jna4vbM3RTUbU7bHhsgwe0t1ddAHtolX0/pub?output=csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Idade                                           1470 non-null   int64
#  1   Demissão                                        1470 non-null   object
#  2   Viagem de negócios                              1470 non-null   object
#  3   Diárias recebidas                               1470 non-null   int64
#  4   Departamento                                    1470 non-null   object
#  5   Distância de Casa                               1470 non-null   int64
#  6   Escolaridade                                    1470 non-null   int64
#  7   Área de Formação                                1470 non-null   object
#  8   Número de contratos de trabalho na empresa      1470 non-null   int64
#  9   ID Funcionário                                  1470 non-null   int64
#  10  Nível de Satisfação com o ambiente de trabalho  1470 non-null   int64
#  11  Gênero                                          1470 non-null   object
#  12  Salário por hora                                1470 non-null   int64
#  13  Nível de envolvimento com o trabalho            1470 non-null   int64
#  14  Nível hierárquico                               1470 non-null   int64
#  15  Cargo                                           1470 non-null   object
#  16  Satisfação com o trabalho                       1470 non-null   int64
#  17  Estado civil                                    1470 non-null   object
#  18  Renda mensal                                    1470 non-null   int64
#  19  Salário Mensal                                  1470 non-null   int64
#  20  qtde de empresas que já trabalhou               1470 non-null   int64
#  21  Maior de idade                                  1470 non-null   object
#  22  Faz hora extra                                  1470 non-null   object
#  23  percentual de aumento de salário                1470 non-null   int64
#  24  score de performance                            1470 non-null   int64
#  25  Satisfação nas relações Não trabalho            1470 non-null   int64
#  26  Jornada padrão de trabalho                      1470 non-null   int64
#  27  opção de remaunração variável em ações          1470 non-null   int64
#  28  Total de anos trabalhados                       1470 non-null   int64
#  29  Qtde de treinamentos realizados no último ano   1470 non-null   int64
#  30  Equilíbrio vida trabalho                        1470 non-null   int64
#  31  Total de anos trabalhados na empresa            1470 non-null   int64
#  32  Anos trabalhados na função atual                1470 non-null   int64
#  33  Anos desde a última promoção                    1470 non-null   int64
#  34  Anos trabalhando com o atual gestor             1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB
